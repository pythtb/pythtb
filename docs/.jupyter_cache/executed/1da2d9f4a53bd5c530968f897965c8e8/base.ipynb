# %%
from pythtb.models import graphene
import matplotlib.pyplot as plt

model = graphene(delta=0, t=-1)

# %%
model.visualize()
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: xlabel='x', ylabel='y'>)

# %%
nodes = [[0, 0], [2/3, 1/3], [1/2, 1/2], [0, 0]]
label = (r"$\Gamma $", r"$K$", r"$M$", r"$\Gamma $")
model.plot_bands(k_nodes=nodes, k_node_labels=label, nk=200)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: ylabel='Energy $E(\\mathbf{{k}})$'>)
